# %%
import pandas as pd
import numpy as np

# %%
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('../data/raw/retail_store.csv')

# %%
sandbox = df.copy()

# %%
sandbox.head()
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# 4            False

# %%
sandbox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  object
#  1   Customer ID       12575 non-null  object
#  2   Category          12575 non-null  object
#  3   Item              11362 non-null  object
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  object
#  8   Location          12575 non-null  object
#  9   Transaction Date  12575 non-null  object
#  10  Discount Applied  8376 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
sandbox.isna().sum()
# Out:
# Transaction ID         0
# Customer ID            0
# Category               0
# Item                1213
# Price Per Unit       609
# Quantity             604
# Total Spent          604
# Payment Method         0
# Location               0
# Transaction Date       0
# Discount Applied    4199
# dtype: int64

# %%
initial_count = len(sandbox)
initial_count
# Out:
# 12575

# %%
sandbox.isnull().sum().sum()
# Out:
# np.int64(7229)

# %% [markdown]
# # Rename columns to title case with underscores #

# %%
sandbox.columns
# Out:
# Index(['Transaction ID', 'Customer ID', 'Category', 'Item', 'Price Per Unit',
#        'Quantity', 'Total Spent', 'Payment Method', 'Location',
#        'Transaction Date', 'Discount Applied'],
#       dtype='object')

# %%
sandbox.columns.to_list()
# Out:
# ['Transaction ID',
#  'Customer ID',
#  'Category',
#  'Item',
#  'Price Per Unit',
#  'Quantity',
#  'Total Spent',
#  'Payment Method',
#  'Location',
#  'Transaction Date',
#  'Discount Applied']

# %%
cols_to_rename = ['Transaction ID',
 'Customer ID',
 'Category',
 'Item',
 'Price Per Unit',
 'Quantity',
 'Total Spent',
 'Payment Method',
 'Location',
 'Transaction Date',
 'Discount Applied']

# %%
sandbox.rename(columns={ col: col.title().replace(' ', '_') for col in cols_to_rename}, inplace=True)

# %%
sandbox.head()
# Out:
#   Transaction_Id Customer_Id       Category          Item  Price_Per_Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total_Spent  Payment_Method Location Transaction_Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount_Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# 4            False

# %% [markdown]
# # Standardize text columns #

# %%
string_cols = sandbox.select_dtypes(include=['object']).columns
string_cols
# Out:
# Index(['Transaction_Id', 'Customer_Id', 'Category', 'Item', 'Payment_Method',
#        'Location', 'Transaction_Date', 'Discount_Applied'],
#       dtype='object')

# %%
terms_to_cleam = ['ERROR', 'error', 'UNKNOWN', 'Unknown', 'NAN', 'nan', 'None', 'Na', '']

# %%
for col in string_cols:
    if col in sandbox.columns:
        sandbox[col] = (
            sandbox[col]
            .astype(str, errors='ignore')
            .str.lower()
            .str.replace(' ', '_')
            .replace(terms_to_cleam, np.nan)
            .str.strip())

# %%
sandbox.head()
# Out:
#   Transaction_Id Customer_Id       Category          Item  Price_Per_Unit  \
# 0    txn_6867343     cust_09     patisserie   item_10_pat            18.5
# 1    txn_3731986     cust_22  milk_products  item_17_milk            29.0
# 2    txn_9303719     cust_02       butchers   item_12_but            21.5
# 3    txn_9458126     cust_06      beverages   item_16_bev            27.5
# 4    txn_4575373     cust_05           food   item_6_food            12.5
#
#    Quantity  Total_Spent  Payment_Method Location Transaction_Date  \
# 0      10.0        185.0  digital_wallet   online       2024-04-08
# 1       9.0        261.0  digital_wallet   online       2023-07-23
# 2       2.0         43.0     credit_card   online       2022-10-05
# 3       9.0        247.5     credit_card   online       2022-05-07
# 4       7.0         87.5  digital_wallet   online       2022-10-02
#
#   Discount_Applied
# 0             true
# 1             true
# 2            false
# 3              NaN
# 4            false

# %% [markdown]
# # Standardize numeric columns #

# %%
numeric_cols = sandbox.select_dtypes(include=('number')).columns
numeric_cols
# Out:
# Index(['Price_Per_Unit', 'Quantity', 'Total_Spent'], dtype='object')

# %%
for col in numeric_cols:
    if col in sandbox.columns:
        sandbox[col] = pd.to_numeric(sandbox[col], errors='coerce')

# %%
sandbox.tail()
# Out:
#       Transaction_Id Customer_Id    Category         Item  Price_Per_Unit  \
# 12570    txn_9347481     cust_18  patisserie  item_23_pat            38.0
# 12571    txn_4009414     cust_03   beverages   item_2_bev             6.5
# 12572    txn_5306010     cust_11    butchers   item_7_but            14.0
# 12573    txn_5167298     cust_04   furniture   item_7_fur            14.0
# 12574    txn_2407494     cust_23        food  item_9_food            17.0
#
#        Quantity  Total_Spent Payment_Method  Location Transaction_Date  \
# 12570       4.0        152.0    credit_card  in-store       2023-09-03
# 12571       9.0         58.5           cash    online       2022-08-12
# 12572      10.0        140.0           cash    online       2024-08-24
# 12573       6.0         84.0           cash    online       2023-12-30
# 12574       3.0         51.0           cash    online       2022-08-06
#
#       Discount_Applied
# 12570              NaN
# 12571            false
# 12572              NaN
# 12573             true
# 12574              NaN

# %%
sandbox['Transaction_Date'] = pd.to_datetime(sandbox['Transaction_Date'], errors='coerce', infer_datetime_format=True)
# Out:
# C:\Users\Renato\AppData\Local\Temp\ipykernel_9152\2056610404.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sandbox['Transaction_Date'] = pd.to_datetime(sandbox['Transaction_Date'], errors='coerce', infer_datetime_format=True)

# %% [markdown]
# # Analysis of the Price_Per_Unit column #

# %% [markdown]
# Upon analyzing the dataset, I observed that the Item and Price_Per_Unit columns could potentially be populated by mapping each item index to its corresponding unit price, given that each index is unique. Nevertheless, there are 609 missing entries in Item and over one thousand in Price_Per_Unit. Considering the presence of the Quantity and Total_Spent columns, it would be more logical to derive the Price_Per_Unit values from them first.

# %%
sandbox['Price_Per_Unit'] = np.where(
    sandbox['Price_Per_Unit'].isna() & (sandbox['Quantity'] > 0), 
    sandbox['Total_Spent'] / sandbox['Quantity'], 
    sandbox['Price_Per_Unit']
)

# %%
sandbox.isna().sum()
# Out:
# Transaction_Id         0
# Customer_Id            0
# Category               0
# Item                1213
# Price_Per_Unit         0
# Quantity             604
# Total_Spent          604
# Payment_Method         0
# Location               0
# Transaction_Date       0
# Discount_Applied    4199
# dtype: int64

# %% [markdown]
# # Analysis of the Category column #

# %%
sandbox['Category'].sort_values().unique()
# Out:
# array(['beverages', 'butchers', 'computers_and_electric_accessories',
#        'electric_household_essentials', 'food', 'furniture',
#        'milk_products', 'patisserie'], dtype=object)

# %%
sandbox['Category'].value_counts()
# Out:
# Category
# electric_household_essentials         1591
# furniture                             1591
# food                                  1588
# milk_products                         1584
# butchers                              1568
# beverages                             1567
# computers_and_electric_accessories    1558
# patisserie                            1528
# Name: count, dtype: int64

# %%
sandbox.groupby('Category')['Item'].unique()
# Out:
# Category
# beverages                             [item_16_bev, nan, item_7_bev, item_25_bev, it...
# butchers                              [item_12_but, item_22_but, item_3_but, item_20...
# computers_and_electric_accessories    [item_16_cea, item_5_cea, item_15_cea, item_24...
# electric_household_essentials         [item_13_ehe, item_4_ehe, item_21_ehe, item_10...
# food                                  [item_6_food, item_1_food, item_2_food, item_1...
# furniture                             [nan, item_16_fur, item_14_fur, item_25_fur, i...
# milk_products                         [item_17_milk, nan, item_16_milk, item_19_milk...
# patisserie                            [item_10_pat, nan, item_24_pat, item_17_pat, i...
# Name: Item, dtype: object

# %%
sandbox.groupby(['Item', 'Category'])['Price_Per_Unit'].unique()
# Out:
# Item          Category
# item_10_bev   beverages                             [18.5]
# item_10_but   butchers                              [18.5]
# item_10_cea   computers_and_electric_accessories    [18.5]
# item_10_ehe   electric_household_essentials         [18.5]
# item_10_food  food                                  [18.5]
#                                                      ...
# item_9_ehe    electric_household_essentials         [17.0]
# item_9_food   food                                  [17.0]
# item_9_fur    furniture                             [17.0]
# item_9_milk   milk_products                         [17.0]
# item_9_pat    patisserie                            [17.0]
# Name: Price_Per_Unit, Length: 200, dtype: object

# %% [markdown]
# Given that each item index holds a unique value. I will extract the corresponding data and build a mapping dictionary to address inaccurate or missing records in the Price_Per_Unit column.

# %%
sandbox['Item'].str.split('_')
# Out:
# 0         [item, 10, pat]
# 1        [item, 17, milk]
# 2         [item, 12, but]
# 3         [item, 16, bev]
# 4         [item, 6, food]
#                ...
# 12570     [item, 23, pat]
# 12571      [item, 2, bev]
# 12572      [item, 7, but]
# 12573      [item, 7, fur]
# 12574     [item, 9, food]
# Name: Item, Length: 12575, dtype: object

# %%
sandbox['Item'].str.split('_').str[1]
# Out:
# 0        10
# 1        17
# 2        12
# 3        16
# 4         6
#          ..
# 12570    23
# 12571     2
# 12572     7
# 12573     7
# 12574     9
# Name: Item, Length: 12575, dtype: object

# %%
sandbox['Item_Number'] = sandbox['Item'].str.split('_').str[1].astype(float)
sandbox['Item_Number']
# Out:
# 0        10.0
# 1        17.0
# 2        12.0
# 3        16.0
# 4         6.0
#          ...
# 12570    23.0
# 12571     2.0
# 12572     7.0
# 12573     7.0
# 12574     9.0
# Name: Item_Number, Length: 12575, dtype: float64

# %%
price_map = sandbox.dropna(subset=['Item_Number', 'Price_Per_Unit']).set_index('Item_Number')['Price_Per_Unit'].to_dict()
price_map
# Out:
# {10.0: 18.5,
#  17.0: 29.0,
#  12.0: 21.5,
#  16.0: 27.5,
#  6.0: 12.5,
#  1.0: 5.0,
#  22.0: 36.5,
#  3.0: 8.0,
#  2.0: 6.5,
#  24.0: 39.5,
#  13.0: 23.0,
#  7.0: 14.0,
#  4.0: 9.5,
#  14.0: 24.5,
#  20.0: 33.5,
#  25.0: 41.0,
#  11.0: 20.0,
#  21.0: 35.0,
#  23.0: 38.0,
#  8.0: 15.5,
#  5.0: 11.0,
#  19.0: 32.0,
#  15.0: 26.0,
#  18.0: 30.5,
#  9.0: 17.0}

# %% [markdown]
# I am imputing the missing (NaN) values utilizing the predefined mapping dictionary.

# %%
sandbox['Item_Number'] = sandbox['Item'].str.split('_').str[1].astype(float)
price_map = sandbox.dropna(subset=['Item_Number', 'Price_Per_Unit']).set_index('Item_Number')['Price_Per_Unit'].to_dict()

sandbox['Price_Per_Unit'] = np.where(
    sandbox['Price_Per_Unit'].isna() & sandbox['Item_Number'].notna(), 
    sandbox['Item_Number'].map(price_map), 
    sandbox['Price_Per_Unit']
)

# %%
sandbox.isna().sum()
# Out:
# Transaction_Id         0
# Customer_Id            0
# Category               0
# Item                1213
# Price_Per_Unit         0
# Quantity             604
# Total_Spent          604
# Payment_Method         0
# Location               0
# Transaction_Date       0
# Discount_Applied    4199
# Item_Number         1213
# dtype: int64

# %% [markdown]
# # Analysis of the Item column #

# %%
sandbox['Item'].sort_values().unique()
# Out:
# array(['item_10_bev', 'item_10_but', 'item_10_cea', 'item_10_ehe',
#        'item_10_food', 'item_10_fur', 'item_10_milk', 'item_10_pat',
#        'item_11_bev', 'item_11_but', 'item_11_cea', 'item_11_ehe',
#        'item_11_food', 'item_11_fur', 'item_11_milk', 'item_11_pat',
#        'item_12_bev', 'item_12_but', 'item_12_cea', 'item_12_ehe',
#        'item_12_food', 'item_12_fur', 'item_12_milk', 'item_12_pat',
#        'item_13_bev', 'item_13_but', 'item_13_cea', 'item_13_ehe',
#        'item_13_food', 'item_13_fur', 'item_13_milk', 'item_13_pat',
#        'item_14_bev', 'item_14_but', 'item_14_cea', 'item_14_ehe',
#        'item_14_food', 'item_14_fur', 'item_14_milk', 'item_14_pat',
#        'item_15_bev', 'item_15_but', 'item_15_cea', 'item_15_ehe',
#        'item_15_food', 'item_15_fur', 'item_15_milk', 'item_15_pat',
#        'item_16_bev', 'item_16_but', 'item_16_cea', 'item_16_ehe',
#        'item_16_food', 'item_16_fur', 'item_16_milk', 'item_16_pat',
#        'item_17_bev', 'item_17_but', 'item_17_cea', 'item_17_ehe',
#        'item_17_food', 'item_17_fur', 'item_17_milk', 'item_17_pat',
#        'item_18_bev', 'item_18_but', 'item_18_cea', 'item_18_ehe',
#        'item_18_food', 'item_18_fur', 'item_18_milk', 'item_18_pat',
#        'item_19_bev', 'item_19_but', 'item_19_cea', 'item_19_ehe',
#        'item_19_food', 'item_19_fur', 'item_19_milk', 'item_19_pat',
#        'item_1_bev', 'item_1_but', 'item_1_cea', 'item_1_ehe',
#        'item_1_food', 'item_1_fur', 'item_1_milk', 'item_1_pat',
#        'item_20_bev', 'item_20_but', 'item_20_cea', 'item_20_ehe',
#        'item_20_food', 'item_20_fur', 'item_20_milk', 'item_20_pat',
#        'item_21_bev', 'item_21_but', 'item_21_cea', 'item_21_ehe',
#        'item_21_food', 'item_21_fur', 'item_21_milk', 'item_21_pat',
#        'item_22_bev', 'item_22_but', 'item_22_cea', 'item_22_ehe',
#        'item_22_food', 'item_22_fur', 'item_22_milk', 'item_22_pat',
#        'item_23_bev', 'item_23_but', 'item_23_cea', 'item_23_ehe',
#        'item_23_food', 'item_23_fur', 'item_23_milk', 'item_23_pat',
#        'item_24_bev', 'item_24_but', 'item_24_cea', 'item_24_ehe',
#        'item_24_food', 'item_24_fur', 'item_24_milk', 'item_24_pat',
#        'item_25_bev', 'item_25_but', 'item_25_cea', 'item_25_ehe',
#        'item_25_food', 'item_25_fur', 'item_25_milk', 'item_25_pat',
#        'item_2_bev', 'item_2_but', 'item_2_cea', 'item_2_ehe',
#        'item_2_food', 'item_2_fur', 'item_2_milk', 'item_2_pat',
#        'item_3_bev', 'item_3_but', 'item_3_cea', 'item_3_ehe',
#        'item_3_food', 'item_3_fur', 'item_3_milk', 'item_3_pat',
#        'item_4_bev', 'item_4_but', 'item_4_cea', 'item_4_ehe',
#        'item_4_food', 'item_4_fur', 'item_4_milk', 'item_4_pat',
#        'item_5_bev', 'item_5_but', 'item_5_cea', 'item_5_ehe',
#        'item_5_food', 'item_5_fur', 'item_5_milk', 'item_5_pat',
#        'item_6_bev', 'item_6_but', 'item_6_cea', 'item_6_ehe',
#        'item_6_food', 'item_6_fur', 'item_6_milk', 'item_6_pat',
#        'item_7_bev', 'item_7_but', 'item_7_cea', 'item_7_ehe',
#        'item_7_food', 'item_7_fur', 'item_7_milk', 'item_7_pat',
#        'item_8_bev', 'item_8_but', 'item_8_cea', 'item_8_ehe',
#        'item_8_food', 'item_8_fur', 'item_8_milk', 'item_8_pat',
#        'item_9_bev', 'item_9_but', 'item_9_cea', 'item_9_ehe',
#        'item_9_food', 'item_9_fur', 'item_9_milk', 'item_9_pat', nan],
#       dtype=object)

# %%
sandbox['Item'].value_counts()
# Out:
# Item
# item_2_bev      126
# item_25_fur     113
# item_11_fur     110
# item_16_milk    109
# item_1_milk     109
#                ...
# item_5_bev        7
# item_13_bev       7
# item_13_fur       7
# item_21_pat       6
# item_3_ehe        5
# Name: count, Length: 200, dtype: int64

# %% [markdown]
# Creates a dictionary (item_map) to uniquely look up the 'Item' name and using the combination of 'Price_Per_Unit' and 'Category' as the key.

# %%
item_map = sandbox.dropna(subset=['Item', 'Price_Per_Unit', 'Category']).set_index(['Price_Per_Unit', 'Category'])['Item'].to_dict()
item_map
# Out:
# {(18.5, 'patisserie'): 'item_10_pat',
#  (29.0, 'milk_products'): 'item_17_milk',
#  (21.5, 'butchers'): 'item_12_but',
#  (27.5, 'beverages'): 'item_16_bev',
#  (12.5, 'food'): 'item_6_food',
#  (5.0, 'food'): 'item_1_food',
#  (27.5, 'furniture'): 'item_16_fur',
#  (36.5, 'butchers'): 'item_22_but',
#  (8.0, 'butchers'): 'item_3_but',
#  (6.5, 'food'): 'item_2_food',
#  (39.5, 'patisserie'): 'item_24_pat',
#  (27.5, 'milk_products'): 'item_16_milk',
#  (29.0, 'patisserie'): 'item_17_pat',
#  (23.0, 'electric_household_essentials'): 'item_13_ehe',
#  (14.0, 'beverages'): 'item_7_bev',
#  (9.5, 'electric_household_essentials'): 'item_4_ehe',
#  (18.5, 'food'): 'item_10_food',
#  (24.5, 'furniture'): 'item_14_fur',
#  (33.5, 'butchers'): 'item_20_but',
#  (41.0, 'furniture'): 'item_25_fur',
#  (24.5, 'food'): 'item_14_food',
#  (36.5, 'patisserie'): 'item_22_pat',
#  (20.0, 'food'): 'item_11_food',
#  (12.5, 'patisserie'): 'item_6_pat',
#  (35.0, 'electric_household_essentials'): 'item_21_ehe',
#  (41.0, 'beverages'): 'item_25_bev',
#  (38.0, 'food'): 'item_23_food',
#  (18.5, 'furniture'): 'item_10_fur',
#  (20.0, 'beverages'): 'item_11_bev',
#  (38.0, 'butchers'): 'item_23_but',
#  (36.5, 'beverages'): 'item_22_bev',
#  (18.5, 'electric_household_essentials'): 'item_10_ehe',
#  (39.5, 'butchers'): 'item_24_but',
#  (15.5, 'beverages'): 'item_8_bev',
#  (8.0, 'food'): 'item_3_food',
#  (21.5, 'food'): 'item_12_food',
#  (27.5, 'computers_and_electric_accessories'): 'item_16_cea',
#  (20.0, 'patisserie'): 'item_11_pat',
#  (27.5, 'butchers'): 'item_16_but',
#  (11.0, 'computers_and_electric_accessories'): 'item_5_cea',
#  (32.0, 'milk_products'): 'item_19_milk',
#  (38.0, 'furniture'): 'item_23_fur',
#  (14.0, 'furniture'): 'item_7_fur',
#  (26.0, 'computers_and_electric_accessories'): 'item_15_cea',
#  (12.5, 'milk_products'): 'item_6_milk',
#  (39.5, 'computers_and_electric_accessories'): 'item_24_cea',
#  (36.5, 'computers_and_electric_accessories'): 'item_22_cea',
#  (36.5, 'food'): 'item_22_food',
#  (6.5, 'butchers'): 'item_2_but',
#  (24.5, 'patisserie'): 'item_14_pat',
#  (21.5, 'patisserie'): 'item_12_pat',
#  (30.5, 'food'): 'item_18_food',
#  (5.0, 'patisserie'): 'item_1_pat',
#  (9.5, 'beverages'): 'item_4_bev',
#  (36.5, 'furniture'): 'item_22_fur',
#  (14.0, 'patisserie'): 'item_7_pat',
#  (33.5, 'computers_and_electric_accessories'): 'item_20_cea',
#  (33.5, 'food'): 'item_20_food',
#  (20.0, 'furniture'): 'item_11_fur',
#  (41.0, 'patisserie'): 'item_25_pat',
#  (14.0, 'food'): 'item_7_food',
#  (35.0, 'furniture'): 'item_21_fur',
#  (39.5, 'furniture'): 'item_24_fur',
#  (15.5, 'milk_products'): 'item_8_milk',
#  (9.5, 'food'): 'item_4_food',
#  (24.5, 'beverages'): 'item_14_bev',
#  (9.5, 'patisserie'): 'item_4_pat',
#  (9.5, 'milk_products'): 'item_4_milk',
#  (14.0, 'computers_and_electric_accessories'): 'item_7_cea',
#  (12.5, 'electric_household_essentials'): 'item_6_ehe',
#  (35.0, 'butchers'): 'item_21_but',
#  (27.5, 'patisserie'): 'item_16_pat',
#  (41.0, 'computers_and_electric_accessories'): 'item_25_cea',
#  (15.5, 'butchers'): 'item_8_but',
#  (18.5, 'computers_and_electric_accessories'): 'item_10_cea',
#  (11.0, 'furniture'): 'item_5_fur',
#  (17.0, 'food'): 'item_9_food',
#  (35.0, 'computers_and_electric_accessories'): 'item_21_cea',
#  (15.5, 'computers_and_electric_accessories'): 'item_8_cea',
#  (15.5, 'electric_household_essentials'): 'item_8_ehe',
#  (38.0, 'milk_products'): 'item_23_milk',
#  (38.0, 'beverages'): 'item_23_bev',
#  (32.0, 'beverages'): 'item_19_bev',
#  (33.5, 'beverages'): 'item_20_bev',
#  (39.5, 'food'): 'item_24_food',
#  (35.0, 'milk_products'): 'item_21_milk',
#  (12.5, 'beverages'): 'item_6_bev',
#  (5.0, 'milk_products'): 'item_1_milk',
#  (39.5, 'milk_products'): 'item_24_milk',
#  (6.5, 'computers_and_electric_accessories'): 'item_2_cea',
#  (30.5, 'butchers'): 'item_18_but',
#  (5.0, 'furniture'): 'item_1_fur',
#  (8.0, 'milk_products'): 'item_3_milk',
#  (20.0, 'milk_products'): 'item_11_milk',
#  (23.0, 'computers_and_electric_accessories'): 'item_13_cea',
#  (12.5, 'computers_and_electric_accessories'): 'item_6_cea',
#  (6.5, 'furniture'): 'item_2_fur',
#  (35.0, 'beverages'): 'item_21_bev',
#  (15.5, 'furniture'): 'item_8_fur',
#  (23.0, 'butchers'): 'item_13_but',
#  (6.5, 'beverages'): 'item_2_bev',
#  (14.0, 'electric_household_essentials'): 'item_7_ehe',
#  (24.5, 'computers_and_electric_accessories'): 'item_14_cea',
#  (32.0, 'electric_household_essentials'): 'item_19_ehe',
#  (30.5, 'computers_and_electric_accessories'): 'item_18_cea',
#  (20.0, 'computers_and_electric_accessories'): 'item_11_cea',
#  (29.0, 'furniture'): 'item_17_fur',
#  (26.0, 'milk_products'): 'item_15_milk',
#  (33.5, 'electric_household_essentials'): 'item_20_ehe',
#  (27.5, 'electric_household_essentials'): 'item_16_ehe',
#  (38.0, 'electric_household_essentials'): 'item_23_ehe',
#  (14.0, 'butchers'): 'item_7_but',
#  (5.0, 'electric_household_essentials'): 'item_1_ehe',
#  (32.0, 'computers_and_electric_accessories'): 'item_19_cea',
#  (41.0, 'food'): 'item_25_food',
#  (21.5, 'electric_household_essentials'): 'item_12_ehe',
#  (36.5, 'electric_household_essentials'): 'item_22_ehe',
#  (23.0, 'patisserie'): 'item_13_pat',
#  (29.0, 'electric_household_essentials'): 'item_17_ehe',
#  (41.0, 'butchers'): 'item_25_but',
#  (9.5, 'computers_and_electric_accessories'): 'item_4_cea',
#  (6.5, 'milk_products'): 'item_2_milk',
#  (5.0, 'butchers'): 'item_1_but',
#  (21.5, 'beverages'): 'item_12_bev',
#  (11.0, 'food'): 'item_5_food',
#  (41.0, 'electric_household_essentials'): 'item_25_ehe',
#  (17.0, 'computers_and_electric_accessories'): 'item_9_cea',
#  (5.0, 'computers_and_electric_accessories'): 'item_1_cea',
#  (26.0, 'furniture'): 'item_15_fur',
#  (26.0, 'patisserie'): 'item_15_pat',
#  (11.0, 'electric_household_essentials'): 'item_5_ehe',
#  (5.0, 'beverages'): 'item_1_bev',
#  (29.0, 'butchers'): 'item_17_but',
#  (8.0, 'beverages'): 'item_3_bev',
#  (23.0, 'food'): 'item_13_food',
#  (20.0, 'electric_household_essentials'): 'item_11_ehe',
#  (17.0, 'milk_products'): 'item_9_milk',
#  (29.0, 'food'): 'item_17_food',
#  (33.5, 'patisserie'): 'item_20_pat',
#  (17.0, 'patisserie'): 'item_9_pat',
#  (18.5, 'beverages'): 'item_10_bev',
#  (29.0, 'computers_and_electric_accessories'): 'item_17_cea',
#  (15.5, 'patisserie'): 'item_8_pat',
#  (23.0, 'milk_products'): 'item_13_milk',
#  (11.0, 'butchers'): 'item_5_but',
#  (36.5, 'milk_products'): 'item_22_milk',
#  (9.5, 'furniture'): 'item_4_fur',
#  (29.0, 'beverages'): 'item_17_bev',
#  (32.0, 'patisserie'): 'item_19_pat',
#  (6.5, 'patisserie'): 'item_2_pat',
#  (24.5, 'butchers'): 'item_14_but',
#  (33.5, 'furniture'): 'item_20_fur',
#  (12.5, 'butchers'): 'item_6_but',
#  (17.0, 'furniture'): 'item_9_fur',
#  (21.5, 'computers_and_electric_accessories'): 'item_12_cea',
#  (26.0, 'electric_household_essentials'): 'item_15_ehe',
#  (11.0, 'patisserie'): 'item_5_pat',
#  (30.5, 'milk_products'): 'item_18_milk',
#  (12.5, 'furniture'): 'item_6_fur',
#  (39.5, 'beverages'): 'item_24_bev',
#  (24.5, 'milk_products'): 'item_14_milk',
#  (21.5, 'furniture'): 'item_12_fur',
#  (30.5, 'beverages'): 'item_18_bev',
#  (38.0, 'computers_and_electric_accessories'): 'item_23_cea',
#  (39.5, 'electric_household_essentials'): 'item_24_ehe',
#  (6.5, 'electric_household_essentials'): 'item_2_ehe',
#  (38.0, 'patisserie'): 'item_23_pat',
#  (26.0, 'food'): 'item_15_food',
#  (15.5, 'food'): 'item_8_food',
#  (26.0, 'beverages'): 'item_15_bev',
#  (33.5, 'milk_products'): 'item_20_milk',
#  (17.0, 'electric_household_essentials'): 'item_9_ehe',
#  (20.0, 'butchers'): 'item_11_but',
#  (30.5, 'electric_household_essentials'): 'item_18_ehe',
#  (11.0, 'milk_products'): 'item_5_milk',
#  (8.0, 'furniture'): 'item_3_fur',
#  (32.0, 'butchers'): 'item_19_but',
#  (8.0, 'computers_and_electric_accessories'): 'item_3_cea',
#  (32.0, 'furniture'): 'item_19_fur',
#  (14.0, 'milk_products'): 'item_7_milk',
#  (17.0, 'beverages'): 'item_9_bev',
#  (18.5, 'butchers'): 'item_10_but',
#  (30.5, 'furniture'): 'item_18_fur',
#  (41.0, 'milk_products'): 'item_25_milk',
#  (9.5, 'butchers'): 'item_4_but',
#  (26.0, 'butchers'): 'item_15_but',
#  (35.0, 'patisserie'): 'item_21_pat',
#  (35.0, 'food'): 'item_21_food',
#  (23.0, 'beverages'): 'item_13_bev',
#  (11.0, 'beverages'): 'item_5_bev',
#  (8.0, 'patisserie'): 'item_3_pat',
#  (23.0, 'furniture'): 'item_13_fur',
#  (30.5, 'patisserie'): 'item_18_pat',
#  (21.5, 'milk_products'): 'item_12_milk',
#  (18.5, 'milk_products'): 'item_10_milk',
#  (27.5, 'food'): 'item_16_food',
#  (32.0, 'food'): 'item_19_food',
#  (24.5, 'electric_household_essentials'): 'item_14_ehe',
#  (8.0, 'electric_household_essentials'): 'item_3_ehe',
#  (17.0, 'butchers'): 'item_9_but'}

# %% [markdown]
# Creates a temporary composite key column by pairing the 'Price_Per_Unit'and 'Category' columns together as tuples.

# %%
sandbox['Price_Category_Key'] = list(zip(sandbox['Price_Per_Unit'], sandbox['Category']))
sandbox['Price_Category_Key']
# Out:
# 0           (18.5, patisserie)
# 1        (29.0, milk_products)
# 2             (21.5, butchers)
# 3            (27.5, beverages)
# 4                 (12.5, food)
#                  ...
# 12570       (38.0, patisserie)
# 12571         (6.5, beverages)
# 12572         (14.0, butchers)
# 12573        (14.0, furniture)
# 12574             (17.0, food)
# Name: Price_Category_Key, Length: 12575, dtype: object

# %%
sandbox['Item'] = np.where(
    sandbox['Item'].isna() & sandbox['Price_Category_Key'].notna(), 
    sandbox['Price_Category_Key'].map(item_map),
    sandbox['Item']
)

# %%
sandbox.isna().sum()
# Out:
# Transaction_Id           0
# Customer_Id              0
# Category                 0
# Item                     0
# Price_Per_Unit           0
# Quantity               604
# Total_Spent            604
# Payment_Method           0
# Location                 0
# Transaction_Date         0
# Discount_Applied      4199
# Item_Number           1213
# Price_Category_Key       0
# dtype: int64

# %% [markdown]
# # Analysis of the Quantity and Total_Spent columns #

# %% [markdown]
# Both fields exhibit nearly identical patterns of missing data, indicating that the same 600 transactions likely account for the gaps in both variables.

# %%
sandbox[sandbox['Total_Spent'].isna() & (sandbox['Quantity'].isna())]
# Out:
#       Transaction_Id Customer_Id                       Category         Item  \
# 7        txn_1372952     cust_21                      furniture  item_20_fur
# 15       txn_1809665     cust_14                      beverages  item_14_bev
# 19       txn_4206593     cust_01                      furniture  item_21_fur
# 25       txn_3481599     cust_05                      furniture  item_24_fur
# 34       txn_1621497     cust_06                     patisserie  item_13_pat
# ...              ...         ...                            ...          ...
# 12527    txn_1069238     cust_23                           food  item_1_food
# 12552    txn_4823896     cust_05                  milk_products  item_3_milk
# 12556    txn_4397672     cust_04                      beverages  item_25_bev
# 12562    txn_7422454     cust_07                       butchers  item_20_but
# 12564    txn_2153066     cust_17  electric_household_essentials  item_17_ehe
#
#        Price_Per_Unit  Quantity  Total_Spent  Payment_Method  Location  \
# 7                33.5       NaN          NaN  digital_wallet  in-store
# 15               24.5       NaN          NaN     credit_card  in-store
# 19               35.0       NaN          NaN  digital_wallet    online
# 25               39.5       NaN          NaN            cash    online
# 34               23.0       NaN          NaN            cash  in-store
# ...               ...       ...          ...             ...       ...
# 12527             5.0       NaN          NaN  digital_wallet  in-store
# 12552             8.0       NaN          NaN            cash  in-store
# 12556            41.0       NaN          NaN     credit_card    online
# 12562            33.5       NaN          NaN            cash    online
# 12564            29.0       NaN          NaN  digital_wallet  in-store
#
#       Transaction_Date Discount_Applied  Item_Number  \
# 7           2024-04-02             true          NaN
# 15          2022-05-11              NaN          NaN
# 19          2025-01-13            false          NaN
# 25          2022-09-08            false          NaN
# 34          2023-02-18              NaN          NaN
# ...                ...              ...          ...
# 12527       2022-08-13            false          NaN
# 12552       2022-07-21            false          NaN
# 12556       2024-11-28             true          NaN
# 12562       2023-04-15              NaN          NaN
# 12564       2024-03-28            false          NaN
#
#                           Price_Category_Key
# 7                          (33.5, furniture)
# 15                         (24.5, beverages)
# 19                         (35.0, furniture)
# 25                         (39.5, furniture)
# 34                        (23.0, patisserie)
# ...                                      ...
# 12527                            (5.0, food)
# 12552                   (8.0, milk_products)
# 12556                      (41.0, beverages)
# 12562                       (33.5, butchers)
# 12564  (29.0, electric_household_essentials)
#
# [604 rows x 13 columns]

# %% [markdown]
# # Analysis of the Discount_Applied column #

# %%
sandbox['Discount_Applied'].value_counts(dropna=False)
# Out:
# Discount_Applied
# true     4219
# NaN      4199
# false    4157
# Name: count, dtype: int64

# %%
sandbox['Discount_Applied'] = sandbox['Discount_Applied'].apply(
    lambda x: 'yes' if x == 'true' else ('not' if x == 'false' else x)
)

# %%
sandbox[sandbox['Discount_Applied'].isna()]
# Out:
#       Transaction_Id Customer_Id       Category          Item  Price_Per_Unit  \
# 3        txn_9458126     cust_06      beverages   item_16_bev            27.5
# 5        txn_7482416     cust_09     patisserie   item_11_pat            20.0
# 14       txn_2490363     cust_09  milk_products  item_16_milk            27.5
# 15       txn_1809665     cust_14      beverages   item_14_bev            24.5
# 17       txn_9634894     cust_15  milk_products  item_16_milk            27.5
# ...              ...         ...            ...           ...             ...
# 12562    txn_7422454     cust_07       butchers   item_20_but            33.5
# 12568    txn_1096134     cust_06           food   item_4_food             9.5
# 12570    txn_9347481     cust_18     patisserie   item_23_pat            38.0
# 12572    txn_5306010     cust_11       butchers    item_7_but            14.0
# 12574    txn_2407494     cust_23           food   item_9_food            17.0
#
#        Quantity  Total_Spent  Payment_Method  Location Transaction_Date  \
# 3           9.0        247.5     credit_card    online       2022-05-07
# 5          10.0        200.0     credit_card    online       2023-11-30
# 14          2.0         55.0  digital_wallet    online       2022-05-22
# 15          NaN          NaN     credit_card  in-store       2022-05-11
# 17         10.0        275.0  digital_wallet    online       2022-04-17
# ...         ...          ...             ...       ...              ...
# 12562       NaN          NaN            cash    online       2023-04-15
# 12568       8.0         76.0  digital_wallet  in-store       2022-06-11
# 12570       4.0        152.0     credit_card  in-store       2023-09-03
# 12572      10.0        140.0            cash    online       2024-08-24
# 12574       3.0         51.0            cash    online       2022-08-06
#
#       Discount_Applied  Item_Number     Price_Category_Key
# 3                  NaN         16.0      (27.5, beverages)
# 5                  NaN          NaN     (20.0, patisserie)
# 14                 NaN         16.0  (27.5, milk_products)
# 15                 NaN          NaN      (24.5, beverages)
# 17                 NaN          NaN  (27.5, milk_products)
# ...                ...          ...                    ...
# 12562              NaN          NaN       (33.5, butchers)
# 12568              NaN          4.0            (9.5, food)
# 12570              NaN         23.0     (38.0, patisserie)
# 12572              NaN          7.0       (14.0, butchers)
# 12574              NaN          9.0           (17.0, food)
#
# [4199 rows x 13 columns]

# %% [markdown]
# Discount_Applied is contextual rather than essential, so the sales can still be analyzed. We’ll therefore populate that field with unknown values.

# %%
sandbox['Discount_Applied'] = sandbox['Discount_Applied'].fillna('unknown')

# %%
sandbox['Discount_Applied'].value_counts(dropna=False)
# Out:
# Discount_Applied
# yes        4219
# unknown    4199
# not        4157
# Name: count, dtype: int64

# %%
sandbox.isna().sum()
# Out:
# Transaction_Id           0
# Customer_Id              0
# Category                 0
# Item                     0
# Price_Per_Unit           0
# Quantity               604
# Total_Spent            604
# Payment_Method           0
# Location                 0
# Transaction_Date         0
# Discount_Applied         0
# Item_Number           1213
# Price_Category_Key       0
# dtype: int64

# %% [markdown]
# # Analysis of the Transaction_Date column #

# %%
sandbox['Day'] = sandbox['Transaction_Date'].dt.day
sandbox['Month'] = sandbox['Transaction_Date'].dt.month
sandbox['Year'] = sandbox['Transaction_Date'].dt.year
sandbox['Quarter'] = sandbox['Transaction_Date'].dt.quarter

# %%
sandbox.tail()
# Out:
#       Transaction_Id Customer_Id    Category         Item  Price_Per_Unit  \
# 12570    txn_9347481     cust_18  patisserie  item_23_pat            38.0
# 12571    txn_4009414     cust_03   beverages   item_2_bev             6.5
# 12572    txn_5306010     cust_11    butchers   item_7_but            14.0
# 12573    txn_5167298     cust_04   furniture   item_7_fur            14.0
# 12574    txn_2407494     cust_23        food  item_9_food            17.0
#
#        Quantity  Total_Spent Payment_Method  Location Transaction_Date  \
# 12570       4.0        152.0    credit_card  in-store       2023-09-03
# 12571       9.0         58.5           cash    online       2022-08-12
# 12572      10.0        140.0           cash    online       2024-08-24
# 12573       6.0         84.0           cash    online       2023-12-30
# 12574       3.0         51.0           cash    online       2022-08-06
#
#       Discount_Applied  Item_Number  Price_Category_Key  Day  Month  Year  \
# 12570          unknown         23.0  (38.0, patisserie)    3      9  2023
# 12571              not          2.0    (6.5, beverages)   12      8  2022
# 12572          unknown          7.0    (14.0, butchers)   24      8  2024
# 12573              yes          7.0   (14.0, furniture)   30     12  2023
# 12574          unknown          9.0        (17.0, food)    6      8  2022
#
#        Quarter
# 12570        3
# 12571        3
# 12572        3
# 12573        4
# 12574        3

# %% [markdown]
# # Eliminates temporary columns and rows lacking critical information #

# %%
drop_cols = ['Item_Number', 'Price_Category_Key']
sandbox = sandbox.dropna(subset=drop_cols)

# %%
final_count = len(sandbox)

# %%
percentage_removed = ((initial_count - final_count) / initial_count) * 100
percentage_removed
# Out:
# 9.646123260437376
